# %% [markdown]
# <a href="https://colab.research.google.com/github/bubibon/AI_ART/blob/master/Train_test_split.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Creating train and test sets.
#
# Our whole dataset is composed by 5000 images of impressionist landscape paintings. For evaluation purposes, it is suggested to keep a test set of images left out during training.
#
# The chosen split is 90% train (4500 images) and 10% test (500 images).

# %%
import os
import shutil

source_folder = "/content/drive/MyDrive/impressionist_landscapes_resized_1024/"
destination_folder = "/content/drive/MyDrive/dataset/"

# fetch all files
for file_name in os.listdir(source_folder):
    # construct full file path
    source = source_folder + file_name
    destination = destination_folder + file_name
    # copy only files
    if os.path.isfile(source):
        shutil.copy(source, destination)
        print('copied', file_name)
# Out:
# copied philip-wilson-steer_a-view-of-barnard-castle-yorkshire-from-the-river.jpg
# copied pierre-auguste-renoir_coastal-landscape-1904.jpg
# copied pierre-auguste-renoir_arabs-by-the-sea.jpg
# copied pierre-auguste-renoir_algiers-the-garden-of-essai-1881.jpg
# copied pierre-auguste-renoir_a-walk-in-the-woods-madame-lecoeur-and-her-children-1870.jpg
# copied pierre-auguste-renoir_children-by-the-sea-in-guernsey-1883.jpg
# copied pierre-auguste-renoir_cagnes-landscape-6.jpg
# copied paul-signac_the-pine-tree-at-st-tropez-1909.jpg
# copied pierre-auguste-renoir_cagnes.jpg
# copied pierre-auguste-renoir_cagnes-landscape-1911.jpg
# copied paul-signac_port-en-bessin-a-cliff-1883.jpg
# copied paul-signac_the-bonaventure-pine-1893-0.jpg
# copied pierre-auguste-renoir_antibes-1893.jpg
# copied pierre-auguste-renoir_chestnut-tree-blooming-1881.jpg
# copied pierre-auguste-renoir_breton-landscape-trees-and-moor-1892.jpg
# copied philip-wilson-steer_landscape-with-trees-in-yorkshire.jpg
# ...

# %%
len(os.listdir("/content/drive/MyDrive/dataset"))
# Out:
# 5000

# %%
import shutil, random, os
dirpath = '/content/drive/MyDrive/dataset/'

filenames = random.sample(os.listdir(dirpath), 500)
for fname in filenames:
    srcpath = '/content/drive/MyDrive/dataset/' + fname
    destDirectory = '/content/drive/MyDrive/Data/test/' + fname
    shutil.move(srcpath, destDirectory)

# %%
len(os.listdir(dirpath))
# Out:
# 4500

# %%
filenames = os.listdir(dirpath)
for fname in filenames:
    srcpath = '/content/drive/MyDrive/dataset/' + fname
    destDirectory = '/content/drive/MyDrive/Data/train/' + fname
    shutil.move(srcpath, destDirectory)

# %%
len(os.listdir("/content/drive/MyDrive/Data/train/"))
# Out:
# 4500

# %%
len(os.listdir(dirpath))
# Out:
# 0
