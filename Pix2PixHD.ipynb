# %% [markdown]
# <a href="https://colab.research.google.com/github/bubibon/AI_ART/blob/master/Pix2PixHD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!git clone https://github.com/NVIDIA/pix2pixHD
# Out:
# Cloning into 'pix2pixHD'...
# remote: Enumerating objects: 340, done.
# remote: Total 340 (delta 0), reused 0 (delta 0), pack-reused 340
# Receiving objects: 100% (340/340), 55.68 MiB | 22.85 MiB/s, done.
# Resolving deltas: 100% (156/156), done.

# %%
# %cd /content/drive/MyDrive/pix2pix/pix2pixHD
# Out:
# /content/drive/MyDrive/pix2pix/pix2pixHD

# %%
# %ls
# Out:
# checkpoints/   dataset_test2/      options/                    scripts/
# _config.yml    encode_features.py  precompute_feature_maps.py  test.py
# data/          imgs/               README.md                   train.py
# datasets/      LICENSE.txt         results/                    util/
# dataset_test/  models/             run_engine.py

# %%
import os

# %% [markdown]
# ## Training pix2pixHD

# %%
# !pip install dominate

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !python train.py --label_nc 0 --no_instance --name hed_pix --tf_log --continue_train --dataroot /content/drive/MyDrive/pix2pix/pix2pixHD/datasets/hed_pix --save_epoch_freq 5 --checkpoints_dir /content/drive/MyDrive/pix2pix/pix2pixHD/checkpoints --which_epoch latest
# Out:
# ------------ Options -------------
# batchSize: 1
# beta1: 0.5
# checkpoints_dir: /content/drive/MyDrive/pix2pix/pix2pixHD/checkpoints
# continue_train: True
# data_type: 32
# dataroot: /content/drive/MyDrive/pix2pix/pix2pixHD/datasets/hed_pix
# debug: False
# display_freq: 100
# display_winsize: 512
# feat_num: 3
# fineSize: 512
# fp16: False
# gpu_ids: [0]
# input_nc: 3
# instance_feat: False
# isTrain: True
# label_feat: False
# label_nc: 0
# lambda_feat: 10.0
# loadSize: 1024
# load_features: False
# load_pretrain:
# local_rank: 0
# lr: 0.0002
# max_dataset_size: inf
# model: pix2pixHD
# nThreads: 2
# n_blocks_global: 9
# n_blocks_local: 3
# n_clusters: 10
# n_downsample_E: 4
# n_downsample_global: 4
# n_layers_D: 3
# n_local_enhancers: 1
# name: hed_pix
# ndf: 64
# nef: 16
# netG: global
# ngf: 64
# niter: 100
# niter_decay: 100
# niter_fix_global: 0
# no_flip: False
# no_ganFeat_loss: False
# no_html: False
# no_instance: True
# no_lsgan: False
# no_vgg_loss: False
# ...

# %% [markdown]
# ## Generating paintings

# %%
# !python test.py  --help
# Out:
# usage: test.py [-h] [--name NAME] [--gpu_ids GPU_IDS]
#                [--checkpoints_dir CHECKPOINTS_DIR] [--model MODEL]
#                [--norm NORM] [--use_dropout] [--data_type {8,16,32}]
#                [--verbose] [--fp16] [--local_rank LOCAL_RANK]
#                [--batchSize BATCHSIZE] [--loadSize LOADSIZE]
#                [--fineSize FINESIZE] [--label_nc LABEL_NC]
#                [--input_nc INPUT_NC] [--output_nc OUTPUT_NC]
#                [--dataroot DATAROOT] [--resize_or_crop RESIZE_OR_CROP]
#                [--serial_batches] [--no_flip] [--nThreads NTHREADS]
#                [--max_dataset_size MAX_DATASET_SIZE]
#                [--display_winsize DISPLAY_WINSIZE] [--tf_log] [--netG NETG]
#                [--ngf NGF] [--n_downsample_global N_DOWNSAMPLE_GLOBAL]
#                [--n_blocks_global N_BLOCKS_GLOBAL]
#                [--n_blocks_local N_BLOCKS_LOCAL]
#                [--n_local_enhancers N_LOCAL_ENHANCERS]
# ...

# %%
# !python test.py --dataroot /content/drive/MyDrive/GENERATED_IMAGES/HED/prova2/hed_pix --name hed_pix --netG global --resize_or_crop none --label_nc 0 --no_instance --which_epoch 50 --how_many 13 --results_dir /content/drive/MyDrive/GENERATED_IMAGES/HED --checkpoints_dir /content/drive/MyDrive/pix2pix/pix2pixHD/checkpoints
# Out:
# ------------ Options -------------
# aspect_ratio: 1.0
# batchSize: 1
# checkpoints_dir: /content/drive/MyDrive/pix2pix/pix2pixHD/checkpoints
# cluster_path: features_clustered_010.npy
# data_type: 32
# dataroot: /content/drive/MyDrive/GENERATED_IMAGES/HED/prova2/hed_pix
# display_winsize: 512
# engine: None
# export_onnx: None
# feat_num: 3
# fineSize: 512
# fp16: False
# gpu_ids: [0]
# how_many: 13
# input_nc: 3
# instance_feat: False
# isTrain: False
# label_feat: False
# label_nc: 0
# loadSize: 1024
# load_features: False
# local_rank: 0
# max_dataset_size: inf
# model: pix2pixHD
# nThreads: 2
# n_blocks_global: 9
# n_blocks_local: 3
# n_clusters: 10
# n_downsample_E: 4
# n_downsample_global: 4
# n_local_enhancers: 1
# name: hed_pix
# nef: 16
# netG: global
# ngf: 64
# niter_fix_global: 0
# no_flip: False
# no_instance: True
# norm: instance
# ntest: inf
# onnx: None
# output_nc: 3
# phase: test
# resize_or_crop: none
# results_dir: /content/drive/MyDrive/GENERATED_IMAGES/HED
# ...
